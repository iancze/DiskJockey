# %%
using image
im = imread();
skim = imToSky(im, 73.);
spec = imToSpec(skim)
# Out:
# 23x2 Array{Float64,2}:
#  1300.38  0.199754
#  1300.39  0.269976
#  1300.39  0.373053
#  1300.39  0.533447
#  1300.39  0.789398
#  1300.39  1.22201
#  1300.39  1.9912
#  1300.4   3.44573
#  1300.4   5.87213
#  1300.4   4.43888
#  1300.4   3.42709
#  1300.4   3.07635
#  1300.41  3.42704
#  1300.41  4.4386
#  1300.41  5.87165
#  1300.41  3.44571
#  1300.41  1.99098
#  1300.41  1.22191
#  1300.42  0.789486
#  1300.42  0.533646
#  1300.42  0.373109
#  1300.42  0.269913
#  1300.42  0.199879

# %%
im.data[100, 100, 11]
# Out:
# 1.3186479761618e-55

# %%
skim.data[100, 100, 11]
# Out:
# 7.819441955298127e-46

# %%
using plot_image
# Out:
# INFO: Loading help data...

# %%
plot_image.plot_spectrum(spec)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fa026cb5400>)

# %%
plot_image.plot_chmaps(skim)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fabe31f34e0>)
