# %%
using image
using plot_image
# Out:
# INFO: Loading help data...

# %%
im = imread();
skim = imToSky(im, 73.);
spec = imToSpec(skim);

# %%
plot_image.plot_spectrum(spec)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f5f99296d68>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f5f998b9940>)

# %%
plot_image.plot_chmaps(skim)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fb2164b1f28>)
