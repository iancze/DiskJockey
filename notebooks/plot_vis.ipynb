# %%
using Autoreload

# %%
arequire("visibilities")
arequire("image")
arequire("plot_vis")
# Out:
# INFO: Loading help data...

# %%
areload()

img = image.imread()
skim = image.imToSky(img, 73.);

outVis = visibilities.transform(skim);
plot_vis.plot_RawModelVis(outVis)
# Out:
# Reloaded visibilites
# (
# 96,95)
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fb3bc8970f0>)
